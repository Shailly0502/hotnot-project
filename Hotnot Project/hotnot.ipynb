# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("D:\Hotnot Project\onelasttrain\TRAIN.csv",na_values=['None','?'])
# Out:
# c:\Users\Hp\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dataset.head()
# Out:
#               race  gender      age weight  admission_type_id  \
# 0        Caucasian  Female   [0-10)    NaN                  6
# 1        Caucasian  Female  [10-20)    NaN                  1
# 2  AfricanAmerican  Female  [20-30)    NaN                  1
# 3        Caucasian    Male  [30-40)    NaN                  1
# 4        Caucasian    Male  [40-50)    NaN                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital payer_code  \
# 0                        25                    1                 1        NaN
# 1                         1                    7                 3        NaN
# 2                         1                    7                 2        NaN
# 3                         1                    7                 2        NaN
# 4                         1                    7                 1        NaN
#
#           medical_specialty  num_lab_procedures  num_procedures  \
# ...

# %%
dataset.count()
# Out:
# race                        69868
# gender                      71236
# age                         71236
# weight                       2348
# admission_type_id           71236
# discharge_disposition_id    71236
# admission_source_id         71236
# time_in_hospital            71236
# payer_code                  34115
# medical_specialty           41672
# num_lab_procedures          71236
# num_procedures              71236
# num_medications             71236
# number_outpatient           71236
# number_emergency            71236
# number_inpatient            71236
# diag_1                      71218
# diag_2                      70925
# diag_3                      69991
# number_diagnoses            71236
# max_glu_serum                4932
# A1Cresult                   11378
# metformin                   71236
# repaglinide                 71236
# nateglinide                 71236
# chlorpropamide              71236
# glimepiride                 71236
# ...

# %%
dataset['race'].value_counts()
# Out:
# Caucasian          51799
# AfricanAmerican    15472
# Hispanic            1348
# Other                892
# Asian                357
# Name: race, dtype: int64

# %%
dataset['gender'].value_counts()
# Out:
# Female             38522
# Male               32713
# Unknown/Invalid        1
# Name: gender, dtype: int64

# %%
dataset=dataset[dataset['gender'] != 'Unknown/Invalid']

# %%
pd.set_option('max_rows', None)

# %%
dataset['race'].value_counts()
# Out:
# Caucasian          51799
# AfricanAmerican    15472
# ?                   1368
# Hispanic            1348
# Other                892
# Asian                357
# Name: race, dtype: int64

# %%
dataset['age'].value_counts()
# Out:
# [70-80)     18453
# [60-70)     15592
# [50-60)     12382
# [80-90)     11274
# [40-50)      7048
# [30-40)      2799
# [90-100)     1769
# [20-30)      1191
# [10-20)       575
# [0-10)        152
# Name: age, dtype: int64

# %%
dataset=dataset.drop(['weight'],axis=1)

# %%
dataset.count()
# Out:
# race                        69867
# gender                      71235
# age                         71235
# admission_type_id           71235
# discharge_disposition_id    71235
# admission_source_id         71235
# time_in_hospital            71235
# payer_code                  34115
# medical_specialty           41671
# num_lab_procedures          71235
# num_procedures              71235
# num_medications             71235
# number_outpatient           71235
# number_emergency            71235
# number_inpatient            71235
# diag_1                      71217
# diag_2                      70924
# diag_3                      69990
# number_diagnoses            71235
# max_glu_serum                4932
# A1Cresult                   11378
# metformin                   71235
# repaglinide                 71235
# nateglinide                 71235
# chlorpropamide              71235
# glimepiride                 71235
# acetohexamide               71235
# ...
